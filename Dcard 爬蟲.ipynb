# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get('https://www.dcard.tw/f/travel')
soup = BeautifulSoup(res.text, "lxml")
data=[]

# %%
res
# Out:
# <Response [200]>

# %%
url = 'https://www.dcard.tw/f/travel'
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:23.0) Gecko/20100101 Firefox/23.0'
}
response = requests.get(url,headers = headers)

# %%
response
# Out:
# <Response [200]>

# %%
for a in soup.find_all("a", {"class":"PostEntry_root_V6g0r"}):
    print(a['href'])
    data.append(a['href'])

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
data
# Out:
# []

# %%
import requests
from bs4 import BeautifulSoup
data1=[]
for j in data:
    res = requests.get('https://www.dcard.tw'+str(j))
    soup = BeautifulSoup(res.text, "lxml")
    for a in soup.find_all("div", {"class":"Post_content_NKEl9"}):
        data1.append(a.text)

# %%
data1
# Out:
# ['在巴爾幹半島有許許多多的國家，柒七與小夥伴們穿梭在幾個國家時，來到了一個特別的國家『阿爾巴尼亞』。許多長輩聽到這個國家\U0001f9d9\U0001f9d9\U0001f9d9都非常有印象～「喔喔～這個國家我知道！」「 當初我們退出聯合國是他們提議的捏 」『 誒？還有人提議？😮😮😮』「 對啊～就是阿爾巴尼亞提議的」雖然，柒七記憶只有蔣介石氣噗噗退出聯合國，（我好丟臉啊～🙈🙈🙈）但，聽完這些，對於這個國家開始有了好奇～想看看這個與我們有些淵源的國家～也想知道他們還記不記得台灣？！我們剛進來就被他的國徽給吸引住了😮😮😮又大又酷的黑色雙頭鷹，就佇立在眼前，特別有一種中古世紀的威風！！！好酷啊～🦅🦅🦅路上兩旁也插著紅色旗面，中間畫著雙頭鷹的國旗。這隻雙頭鷹其實是他們的民族英雄的象徵，也因這隻雙頭鷹，這個國家有了『 山鷹之國 』的稱號。我們來到的是阿爾巴尼亞的首都『地拉那』在進市區的周邊，可以看到理髮院、麵包店、雜貨店、牙醫等走的風格是比較純樸的路線，不過，越進入市中心，越來越繁華✨✨✨～聽說，阿爾巴尼亞這幾年來一直在積極蛻變。其實柒七覺得在國土上留下歷史的痕跡，挺好的。不管這段歷史，帶來了什麼，改變了什麼，和現在有什麼不同，都是有意義的存在。進到斯坎德培廣場，就被旋轉木馬吸引了～🎠🎠🎠這座旋轉木馬超精緻超美的啊啊啊🦄🦄🦄旁邊就是剛剛說的阿爾巴尼亞名族英雄『 斯坎德培 』阿爾巴尼亞國家歷史博物館，上面繪製共產時期人們革命保衛國家的英姿濃濃的共產主義風格，加上巨大的篇幅與氣勢✨✨✨是在歐洲少見的特色景點。也許，阿爾巴尼亞跟我們之間有個奇妙的緣分吧～他們是知道台灣的～因為在阿爾巴尼亞，有個廣場就叫做台灣廣場～🤘🤘🤘年輕人們經常相約時說：「 我們台灣見～！」為什麼取名為台灣廣場呢？有人說：因為公園的噴水池是台灣建造的。（❓❓❓）又有人說：在年輕一輩的眼裡，中國代表著共產，台灣代表著自由民主。年輕人排斥共產，所以與政府唱反調，暗地取名台灣廣場。（❓❓❓）還聽說：中國幫忙投資阿爾巴尼亞很多，阿爾巴尼亞為了投其所好，把廣場取名為台灣。（❓❓❓）各式各樣的說法，雖然聽的霧煞煞，不過，我想阿而巴尼亞人非常知道台灣這個名字的～哈哈哈這樣也不錯，我們彼此都有了一股親切的熟悉感～😳😳😳在走走逛逛，通過和平鐘期許世界和平～☮☮☮又會看到一個指標性的景點～地拉那金字塔，又稱「自由羅生門」當年
# ...

# %%
import requests
from bs4 import BeautifulSoup
import requests, json
res = requests.get('https://www.dcard.tw/_api/forums/tvepisode/posts?popular=true')
soup = BeautifulSoup(res.text, "lxml")
reqsjson = json.loads(res.text)

# %%
reqsjson
# Out:
# [{'id': 230031445,
#   'title': '#二更 聲林之王 別成為下一個霸凌者',
#   'excerpt': '#更，謝謝大家理性的討論，每個人的留言我都看完了，原諒我沒有一一回覆，沒錯 她的實力在選手中算是普通，但是鏡頭卻這麼多，可能很讓人不能理解，加上贏了之後的雀躍尖叫，可能會讓人覺得不受尊重，我想這也是在比賽中',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': 'ba0145a2-adff-4229-9a84-9b26ebd2f7f0',
#   'replyId': None,
#   'createdAt': '2018-11-10T03:03:51.197Z',
#   'updatedAt': '2018-11-10T16:29:28.011Z',
#   'commentCount': 31,
#   'likeCount': 234,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['聲林之王'],
#   'forumName': '戲劇綜藝',
#   'forumAlias': 'tvepisode',
#   'gender': 'F',
#   'school': '國立高雄師範大學',
#   'replyTitle': None,
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 231},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 2},
#    {'id': 'aa0d425f-d530-4478-9a77-fe3aedc79eea', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'withImages': True,
#   'withVideos': False,
# ...

# %%
print(BeautifulSoup(reqsjson[0]['title']).text)
# Out:
# #二更 聲林之王 別成為下一個霸凌者
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
