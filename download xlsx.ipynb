# %%
from bs4 import BeautifulSoup
import requests

# %%
r = requests.get('https://www.taoyuanairport.com.tw/company_ch/Fos')

# %%
res = requests.get('https://www.taoyuanairport.com.tw/company_ch/Fos')
res.encoding = 'utf-8'
soup = BeautifulSoup(res.text,"html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="中文" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta content="no-cache" http-equiv="cache-control"/>
# <meta content="no-cache" http-equiv="pragma"/>
# <meta content="0" http-equiv="expires"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="臺灣桃園國際機場全球資訊網中文版" name="DC.Title"/>
# <meta content="臺灣桃園國際機場全球資訊網" name="DC.Subject"/>
# <meta content="臺灣桃園國際機場全球資訊網" name="DC.Description"/>
# <meta content="臺灣桃園國際機場全球資訊網" name="DC.KeyWords"/>
# <meta content="桃園國際機場股份有限公司" name="DC.Contributor"/>
# <meta content="桃園國際機場股份有限公司" name="DC.Creator"/>
# <meta content="null" name="DC.Type"/>
# <meta content="null" name="DC.Format"/>
# <meta content="" name="DC.Source"/>
# <meta content="null" name="DC.Language"/>
# <meta content="2011-12-31" name="DC.Coverage.t.Max"/>
# <meta content="2009-12-31" name="DC.Coverage.t.Min"/>
# <meta content="桃園國際機場股份有限公司" name="DC.Publisher"/>
# ...

# %%
b_tag = soup.find("table", class_ = "styleline3")
b_tag
# Out:
# <table border="0" cellpadding="0" cellspacing="0" class="styleline3" rules="rows" style="text-align: center;" summary="航班運量整點人數預報表" width="700"><caption>航班運量整點人數預報表</caption>
# <tbody>
# <tr style="background:#CFEBEF"><th class="style20" scope="col">每日初版</th><th class="style20" scope="col">每小時更新版</th></tr>
# <tr style="height:35px">
# <td><a href="/uploads/cp_documents/fos/2019_11_21.xls" style="color: #449bb5;" target="_self" title="2019_11_21_航班運量整點人數預報表.xls">2019_11_21_航班運量整點人數預報表.xls</a></td>
# <td>
# </td>
# </tr>
# <tr style="height:35px">
# <td><a href="/uploads/cp_documents/fos/2019_11_20.xls" style="color: #449bb5;" target="_self" title="2019_11_20_航班運量整點人數預報表.xls">2019_11_20_航班運量整點人數預報表.xls</a></td>
# <td>
# <a href="/uploads/cp_documents/fos/2019_11_20_update.xls" style="color: #ec652c;" target="_self" title="2019_11_20_航班運量整點人數預報表 [更新版].xls">2019_11_20_航班運量整點人數預報表 [更新版].xls</a>
# </td>
# </tr>
# <tr style="height:35px">
# ...

# %%
"https://www.taoyuanairport.com.tw/"+i['href']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-122-1396191ef914> in <module>
# ----> 1 "https://www.taoyuanairport.com.tw/"+i['href']
#
# TypeError: 'int' object is not subscriptable

# %%
list_ =[]
b = b_tag.find_all("a")
for i in b:
    list_.append("https://www.taoyuanairport.com.tw/"+i['href'])

# %%
import requests
for i in range(len(list_)):
    dls =list_[i]
    resp = requests.get(dls)

    output = open('{}.xls'.format(i), 'wb')
    output.write(resp.content)
    output.close()
